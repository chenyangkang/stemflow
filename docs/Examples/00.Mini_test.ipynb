# %% [markdown]
# # Run a mini test
# Yangkang Chen<br>
# Sep 12, 2023

# %%
from stemflow.mini_test import run_mini_test

# %%
cls_fig = run_mini_test(delet_tmp_files=False, show=True)
# Out:
# Start Runing Mini-test...
# Temporary files will be stored at: ./stemflow_mini_test/
# Temporary files will *NOT* be deleted.
# Requesting data from https://chenyangkang.github.io/stemflow/mini_data/mini_data.csv ...
# Done.
# ST_train_test_split ...
# Done.
# Importing stemflow modules...
# Done.
# Declaring model instance...
# Done.
# Fitting model...
# ...
# training: 100%|██████████| 1482/1482 [00:55<00:00, 26.48it/s]
# Done.
# Calculating feature importances...
# Done.
# Assigning importance to points...
# 100%|██████████| 5/5 [02:54<00:00, 34.96s/it]
# Done.
# effort_distance_km                        0.053370
# elevation_mean                            0.045103
# DOY_predictor                             0.044855
# slope_mean                                0.044105
# duration_minutes                          0.043818
# obsvr_species_count                       0.039610
# time_observation_started_minute_of_day    0.036118
# northness_mean                            0.034768
# ...

# %%
cls_fig
