# %% [markdown]
# # Run a mini test
# Yangkang Chen<br>
# Sep 12, 2023

# %%
from stemflow.mini_test import run_mini_test

# %%
cls_fig = run_mini_test(delet_tmp_files=False, show=True)
# Out:
# Start Runing Mini-test...
# Temporary files will be stored at: ./stemflow_mini_test/
# Temporary files will *NOT* be deleted.
# Mini-data already downloaded.
# ST_train_test_split ...
# Done.
# Importing stemflow modules...
# Done.
# Declaring model instance...
# Done.
# Fitting model...
# ...
# training: 100%|██████████| 1490/1490 [00:14<00:00, 100.94it/s]
# Done.
# Calculating feature importances...
# Done.
# Assigning importance to points...
# 100%|██████████| 5/5 [01:32<00:00, 18.56s/it]
# Done.
# effort_distance_km                        0.057558
# northness_mean                            0.049634
# duration_minutes                          0.045484
# obsvr_species_count                       0.042821
# DOY_predictor                             0.041611
# slope_mean                                0.041372
# eastness_mean                             0.038342
# elevation_mean                            0.037905
# time_observation_started_minute_of_day    0.037812
# ...

# %%
cls_fig
