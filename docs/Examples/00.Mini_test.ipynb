# %% [markdown]
# # Run a mini test
# Yangkang Chen<br>
# Jan 14, 10

# %% [markdown]
# This Notebook is to show what tests have been done at each PR/push, and may indicate some basic functionality of `stemflow`.
#
# For detailed explanation of procedures, please see [AdaSTEM demo](https://chenyangkang.github.io/stemflow/Examples/01.AdaSTEM_demo.html)

# %%
from stemflow.manually_testing import run_mini_test

# %%
model = run_mini_test(delet_tmp_files=False, show=True, speed_up_times=2, tmp_dir='./stemflow_mini_test/')
# Out:
# Start Running Mini-test...
# Temporary files will be stored at: ./stemflow_mini_test/
# Temporary files will *NOT* be deleted.
# Requesting data from https://chenyangkang.github.io/stemflow/mini_data/mini_data.pkl ...
# Done.
# Installation path: /Users/chenyangkang/miniforge3/lib/python3.9/site-packages/stemflow
# ST_train_test_split ...
# Done.
# Importing stemflow modules...
# Done.
# Declaring model instance...
# Fold: 2, min_req: 1
# Done.
# Fitting model...
# ...
# training: 100%|██████████| 3189/3189 [01:28<00:00, 36.13it/s]
# Done.
# Calculating feature importances...
# Done.
# Assigning importance to points...
# 100%|██████████| 2/2 [01:17<00:00, 38.85s/it]
# Done.
# duration_minutes                          0.098863
# DOY_predictor                             0.053111
# elevation_mean                            0.046590
# time_observation_started_minute_of_day    0.045889
# bio4                                      0.042878
# eastness_mean                             0.037113
# ...

# %%
# Plot the figure
model.gridding_plot

# %%
from watermark import watermark
print(watermark())
print(watermark(packages="stemflow,numpy,scipy,pandas,xgboost,tqdm,matplotlib,geopandas,scikit-learn"))
# Out:
# Last updated: 2024-01-10T20:06:32.107609+08:00
#
# Python implementation: CPython
# Python version       : 3.9.7
# IPython version      : 8.14.0
#
# Compiler    : Clang 11.1.0
# OS          : Darwin
# Release     : 21.6.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 8
# Architecture: 64bit
#
# stemflow    : 1.0.9.3
# numpy       : 1.24.3
# scipy       : 1.10.1
# pandas      : 2.0.3
# xgboost     : 1.7.6
# tqdm        : 4.65.0
# matplotlib  : 3.7.1
# geopandas   : 0.11.1
# scikit-learn: 0.0
