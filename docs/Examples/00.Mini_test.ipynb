# %% [markdown]
# # Run a mini test
# Yangkang Chen<br>
# Nov 5, 2023

# %%
from stemflow.mini_test import run_mini_test

# %%
model_fig = run_mini_test(delet_tmp_files=False, show=True, speed_up_times=2)
# Out:
# Start Running Mini-test...
# Temporary files will be stored at: ./stemflow_mini_test/
# Temporary files will *NOT* be deleted.
# Requesting data from https://chenyangkang.github.io/stemflow/mini_data/mini_data.pkl ...
# Done.
# Installation path: /Users/chenyangkang/miniforge3/lib/python3.9/site-packages/stemflow
# ST_train_test_split ...
# Done.
# Importing stemflow modules...
# Done.
# Declaring model instance...
# Done.
# Fitting model...
# ...
# training: 100%|██████████| 2947/2947 [01:32<00:00, 31.77it/s]
# Done.
# Calculating feature importances...
# Done.
# Assigning importance to points...
# 100%|██████████| 2/2 [01:13<00:00, 36.98s/it]
# Done.
# duration_minutes                          0.097016
# DOY_predictor                             0.053041
# elevation_mean                            0.048067
# time_observation_started_minute_of_day    0.044581
# slope_mean                                0.040843
# eastness_mean                             0.037028
# ...

# %%
model_fig
