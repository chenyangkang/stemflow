# %% [markdown]
# # Run a mini test
# Yangkang Chen<br>
# Sep 12, 2023

# %%
from stemflow.mini_test import run_mini_test

# %%
run_mini_test(delet_tmp_files=False, show=True)
# Out:
# Start Runing Mini-test...
# Temporary files will be stored at: ./stemflow_mini_test/
# Temporary files will *NOT* be deleted.
# Mini-data already downloaded.
# ST_train_test_split ...
# Done.
# Importing stemflow modules...
# Done.
# Declaring model instance...
# Done.
# Fitting model...
# ...
# training: 100%|██████████| 1577/1577 [00:23<00:00, 66.55it/s]
# Done.
# Calculating feature importances...
# Done.
# Assigning importance to points...
# 100%|██████████| 5/5 [03:23<00:00, 40.63s/it]
# Done.
# effort_distance_km                        0.054171
# eastness_mean                             0.042868
# DOY_predictor                             0.040832
# elevation_mean                            0.040778
# obsvr_species_count                       0.040661
# slope_mean                                0.039032
# duration_minutes                          0.037779
# northness_mean                            0.037280
# time_observation_started_minute_of_day    0.032926
# ...
