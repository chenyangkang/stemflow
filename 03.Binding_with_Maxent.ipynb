# %% [markdown]
# # Using Maxent as base model
# Yangkang Chen<br>
# Sep 5, 2023

# %%
import pandas as pd
import numpy as np
import random
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import matplotlib
import warnings
import pickle
import geopandas as gpd
import os
import json

# matplotlib.style.use('ggplot')
# plt.rcParams['axes.facecolor']='w'
# warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
data = pd.read_csv(f'./BirdSTEM/dataset/test_data/Sample_data_Mallard.csv')

# %% [markdown]
# # Get X and y

# %%
X = data.drop('count', axis=1)
y = data['count'].values

# %% [markdown]
# # First thing first: Spatio-temporal train test split

# %%
from BirdSTEM.model_selection import ST_train_test_split
X_train, X_test, y_train, y_test = ST_train_test_split(X, y, 
                                                       Spatio_blocks_count = 50, Temporal_blocks_count=50,
                                                       random_state=42, test_size=0.3)

# %% [markdown]
# # Train AdaSTEM hurdle model

# %%
from BirdSTEM.model.AdaSTEM import AdaSTEM, AdaSTEMClassifier, AdaSTEMRegressor
from xgboost import XGBClassifier, XGBRegressor
from BirdSTEM.model.Hurdle import Hurdle_for_AdaSTEM, Hurdle
import elapid as ela

# %%
model = AdaSTEMClassifier(base_model=ela.MaxentModel(transform='cloglog', beta_multiplier=2.0),
                                save_gridding_plot = True,
                                ensemble_fold=10, 
                                min_ensemble_required=7,
                                grid_len_lon_upper_threshold=50,
                                grid_len_lon_lower_threshold=5,
                                grid_len_lat_upper_threshold=50,
                                grid_len_lat_lower_threshold=5,
                                temporal_step=50,
                                temporal_bin_interval=50,
                                points_lower_threshold=100)

# %%
# new_X_train = X_train.copy()
# new_X_train['y_'] = y_train
# new_X_train = new_X_train.sample(5000)
# new_X_train.iloc[:,:-1], np.where(new_X_train.iloc[:,-1].values>0,1,0)

# %%
model.fit(X_train, np.where(y_train>0,1,0))
# Out:
# Generating Ensemble: 100%|██████████| 10/10 [00:14<00:00,  1.47s/it]
# training: 100%|██████████| 13142/13142 [1:57:47<00:00,  1.86it/s]

# %%
with open('./test_output/maxent_adastem.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
pred_adastem = model.predict(X_test)

# %%
pred_df = pd.DataFrame({
            'y_true':y_test.flatten(),
            'y_pred_adastem':np.where(pred_adastem.flatten()<0, 0, pred_adastem.flatten()),
        }).dropna()

# %%
metric_dict = AdaSTEM.eval_STEM_res('hurdle', np.array(pred_df.y_true).flatten(), 
                                            np.where(np.array(pred_df.y_pred_adastem).flatten()<0, 0, np.array(pred_df.y_pred_adastem).flatten())
                                            )

# %%
with open('./test_output/Maxent_AdasTEM_metrics.json', 'w') as f:
    json.dump(metric_dict, f)

# %%
dict([(a,b) for a,b in metric_dict.items() if a in ['AUC','kappa','f1','precision','recall','average_precision']])
# Out:
# {'AUC': 0.7110742597058116,
#  'kappa': 0.3594605543477699,
#  'f1': 0.512802988882814,
#  'precision': 0.43125910031420034,
#  'recall': 0.6323744240925947,
#  'average_precision': 0.34673055053552077}

# %% [markdown]
# # Compare to simple Maxent model

# %%
model_me = ela.MaxentModel(transform='cloglog', beta_multiplier=2.0)

# %%
model_me.fit(X_train.drop(['longitude','latitude'], axis=1), np.where(y_train>0,1,0))
# Out:
# MaxentModel(beta_multiplier=2.0)

# %%
with open('./test_output/maxent_simple.pkl', 'wb') as f:
    pickle.dump(model_me, f)

# %%
X_test.drop(['longitude','latitude'], axis=1)
# Out:
#         DOY  duration_minutes  Traveling  Stationary  Area  \
# 5        47              45.0          0           1     0
# 12       89              76.0          1           0     0
# 13      275              37.0          1           0     0
# 14      251              90.0          1           0     0
# 15      296              30.0          0           1     0
# ...     ...               ...        ...         ...   ...
# 399987  117             103.0          1           0     0
# 399990   69               8.0          1           0     0
# 399993  334               5.0          0           1     0
# 399994  230              60.0          1           0     0
# 399999  235              38.0          1           0     0
#
#         effort_distance_km  number_observers  obsvr_species_count  \
# 5                   -1.000               1.0                 55.0
# 12                   3.315               2.0                172.0
# 13                   2.300               1.0                720.0
# 14                   0.805               1.0                590.0
# 15                  -1.000               1.0                 84.0
# ...                    ...               ...                  ...
# 399987               3.856               4.0                248.0
# 399990               0.130               1.0                160.0
# 399993              -1.000               1.0                297.0
# 399994               1.609               1.0                375.0
# 399999               0.644               2.0                163.0
#
#         time_observation_started_minute_of_day  elevation_mean  slope_mean  \
# 5                                          430     2084.500000    1.474975
# 12                                         814      395.388900    2.308504
# 13                                        1009      264.888900    5.350314
# 14                                         510      141.222230    2.794508
# 15                                         540       52.944447    2.603995
# ...                                        ...             ...         ...
# 399987                                     998      213.277770    0.808984
# 399990                                     590        0.000000    0.053453
# 399993                                     773        3.500000    0.660273
# 399994                                     523        9.722222    0.165324
# 399999                                     985      300.277800    1.964185
#
#         eastness_mean  northness_mean       bio1       bio2       bio3  \
# 5           -0.705554       -0.279949  11.873589  12.150509  33.769915
# 12           0.055726       -0.006490   7.243620   8.839642  21.304950
# 13           0.243507        0.037571  15.132397   9.813581  37.641997
# 14          -0.154491       -0.031299  13.595076   7.823010  24.654766
# 15           0.060170       -0.047103  10.923443   6.195472  31.186498
# ...               ...             ...        ...        ...        ...
# 399987      -0.156508        0.026345  12.377936   8.892305  25.787919
# 399990      -0.001716        0.015291  -1.000000  -1.000000  -1.000000
# 399993      -0.050625        0.165530  27.440800   2.173208  50.560509
# 399994       0.049576        0.010508  11.121199   6.797107  35.207923
# 399999       0.213553       -0.446227  14.937575   8.438638  28.224762
#
#                bio4       bio5       bio6       bio7       bio8       bio9  \
# 5        871.207969  29.855962  -6.124314  35.980276  23.600977  17.788865
# 12      1112.647946  27.783987 -13.707036  41.491023  23.070757  -7.854962
# 13       544.142596  30.478132   4.407302  26.070830  14.176979  19.783638
# 14       799.068812  31.303647  -0.426568  31.730216   9.913604  15.234011
# 15       497.756412  22.305800   2.439920  19.865880   5.365580  18.067261
# ...             ...        ...        ...        ...        ...        ...
# 399987   890.096242  29.932637  -4.549809  34.482446  15.757534  23.853752
# 399990    -1.000000  -1.000000  -1.000000  -1.000000  -1.000000  -1.000000
# 399993    62.751009  29.554719  25.256487   4.298232  27.629019  27.418639
# 399994   428.067975  22.086899   2.781283  19.305616   6.783609  12.981573
# 399999   707.802838  30.386183   0.488188  29.897995   5.882799  21.172930
#
#             bio10      bio11     bio12     bio13     bio14     bio15  \
# 5       22.968558   0.133504  0.036888  0.006928  0.000720  0.000003
# 12      22.174463  -6.952804  0.086734  0.025014  0.000926  0.000058
# 13      22.081275   8.399152  0.110303  0.020415  0.001847  0.000026
# 14      24.641929   3.566562  0.164129  0.024047  0.005409  0.000031
# 15      17.753206   5.325704  0.257844  0.059043  0.004477  0.000212
# ...           ...        ...       ...       ...       ...       ...
# 399987  23.961534   0.402520  0.127413  0.022590  0.002771  0.000029
# 399990  -1.000000  -1.000000 -1.000000 -1.000000 -1.000000 -1.000000
# 399993  28.143704  26.472626  0.203693  0.045899  0.003085  0.000220
# 399994  16.814158   6.157729  0.099681  0.013711  0.001484  0.000017
# 399999  24.148022   5.520584  0.205616  0.032398  0.006111  0.000043
#
#            bio16     bio17     bio18     bio19  closed_shrublands  \
# 5       0.015758  0.003600  0.009808  0.009323                0.0
# 12      0.057456  0.003294  0.057456  0.005661                0.0
# 13      0.049038  0.010666  0.017080  0.026240                0.0
# 14      0.065412  0.021523  0.042120  0.044549                0.0
# 15      0.124012  0.020481  0.022377  0.106117                0.0
# ...          ...       ...       ...       ...                ...
# 399987  0.053915  0.014413  0.022958  0.027138                0.0
# 399990 -1.000000 -1.000000 -1.000000 -1.000000                0.0
# 399993  0.118625  0.009861  0.034195  0.016353                0.0
# 399994  0.039509  0.009661  0.033293  0.021796                0.0
# 399999  0.073977  0.025495  0.041248  0.069816                0.0
#
#         cropland_or_natural_vegetation_mosaics  croplands  \
# 5                                     0.000000   0.000000
# 12                                    0.000000   0.944444
# 13                                    0.000000   0.000000
# 14                                    0.000000   0.111111
# 15                                    0.000000   0.000000
# ...                                        ...        ...
# 399987                                0.000000   1.000000
# 399990                                0.000000   0.000000
# 399993                                0.000000   0.000000
# 399994                                0.027778   0.972222
# 399999                                0.000000   0.000000
#
#         deciduous_broadleaf_forests  deciduous_needleleaf_forests  \
# 5                          0.000000                           0.0
# 12                         0.000000                           0.0
# 13                         0.138889                           0.0
# 14                         0.138889                           0.0
# 15                         0.000000                           0.0
# ...                             ...                           ...
# 399987                     0.000000                           0.0
# 399990                     0.000000                           0.0
# 399993                     0.000000                           0.0
# 399994                     0.000000                           0.0
# 399999                     0.222222                           0.0
#
#         evergreen_broadleaf_forests  evergreen_needleleaf_forests  grasslands  \
# 5                               0.0                      0.000000    0.944444
# 12                              0.0                      0.000000    0.055556
# 13                              0.0                      0.000000    0.722222
# 14                              0.0                      0.000000    0.000000
# 15                              0.0                      0.111111    0.000000
# ...                             ...                           ...         ...
# 399987                          0.0                      0.000000    0.000000
# 399990                          0.0                      0.000000    0.000000
# 399993                          0.0                      0.000000    0.000000
# 399994                          0.0                      0.000000    0.000000
# 399999                          0.0                      0.000000    0.000000
#
#         mixed_forests  non_vegetated_lands  open_shrublands  \
# 5            0.000000                  0.0         0.055556
# 12           0.000000                  0.0         0.000000
# 13           0.138889                  0.0         0.000000
# 14           0.000000                  0.0         0.000000
# 15           0.000000                  0.0         0.000000
# ...               ...                  ...              ...
# 399987       0.000000                  0.0         0.000000
# 399990       0.000000                  0.0         0.000000
# 399993       0.000000                  0.0         0.000000
# 399994       0.000000                  0.0         0.000000
# 399999       0.000000                  0.0         0.000000
#
#         permanent_wetlands  savannas  urban_and_built_up_lands  water_bodies  \
# 5                      0.0  0.000000                  0.000000      0.000000
# 12                     0.0  0.000000                  0.000000      0.000000
# 13                     0.0  0.000000                  0.000000      0.000000
# 14                     0.0  0.138889                  0.000000      0.000000
# 15                     0.0  0.000000                  0.888889      0.000000
# ...                    ...       ...                       ...           ...
# 399987                 0.0  0.000000                  0.000000      0.000000
# 399990                 0.0  0.000000                  0.027778      0.972222
# 399993                 0.0  0.000000                  0.000000      1.000000
# 399994                 0.0  0.000000                  0.000000      0.000000
# 399999                 0.0  0.083333                  0.027778      0.000000
#
#         woody_savannas   entropy
# 5             0.000000  0.214559
# 12            0.000000  0.214559
# 13            0.000000  0.783383
# 14            0.611111  1.093450
# 15            0.000000  0.348832
# ...                ...       ...
# 399987        0.000000 -0.000000
# 399990        0.000000  0.126931
# 399993        0.000000 -0.000000
# 399994        0.000000  0.126931
# 399999        0.666667  0.911167
#
# [116224 rows x 49 columns]

# %%
pred_me = model_me.predict(X_test.drop(['longitude','latitude'], axis=1))

# %%
pred_df = pd.DataFrame({
    'y_true':y_test.flatten(),
    'y_pred':np.where(pred_me.flatten()>0.5, 1, 0)
}).dropna()

# %%
metrics_me = AdaSTEM.eval_STEM_res('hurdle', pred_df.y_true, pred_df.y_pred)

# %%
with open('./test_output/Maxent_simple_metrics.json', 'w') as f:
    json.dump(metrics_me, f)

# %%
dict([(a,b) for a,b in metrics_me.items() if a in ['AUC','kappa','f1','precision','recall','average_precision']])
# Out:
# {'AUC': 0.7170955508504191,
#  'kappa': 0.320510630875698,
#  'f1': 0.466673915407198,
#  'precision': 0.3572201414898044,
#  'recall': 0.672832732403198,
#  'average_precision': 0.29421951675350466}
